# %%
import nest_asyncio
import os

os.chdir("/home/carnufex/butlerbot")

nest_asyncio.apply()

# %%
from news_grabber import get_personalized_news

get_personalized_news()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 from news_grabber import get_personalized_news
#       2 get_personalized_news()
#
# ModuleNotFoundError: No module named 'news_grabber'

# %%
from newsapi import NewsApiClient
from typing import List, Dict
from datetime import datetime, timedelta
from src.settings import settings


class NewsFetcher:
    def __init__(self, api_key: str):
        """Initialize NewsAPI client with your API key."""
        self.api = NewsApiClient(api_key=api_key)

    def get_personalized_news(
        self,
        topics: List[str],
        preferred_sources: List[str] = None,
        days_back: int = 7,
        language: str = "en",
    ) -> List[Dict]:
        """
        Fetch news based on personal preferences.

        Args:
            topics: List of topics/keywords to search for
            preferred_sources: List of preferred news sources (domains)
            days_back: How many days back to search
            language: Language of news articles

        Returns:
            List of news articles matching criteria
        """
        # Calculate date range
        end_date = datetime.now()
        start_date = end_date - timedelta(days=days_back)

        all_articles = []

        # Search for each topic
        for topic in topics:
            query = topic

            # Add source filtering if specified
            if preferred_sources:
                domains = ",".join(preferred_sources)
                query = f"{query} AND domains:{domains}"

            try:
                response = self.api.get_everything(
                    q=query,
                    from_param=start_date.strftime("%Y-%m-%d"),
                    to=end_date.strftime("%Y-%m-%d"),
                    language=language,
                    sort_by="relevancy",
                )

                if response["status"] == "ok":
                    all_articles.extend(response["articles"])

            except Exception as e:
                print(f"Error fetching news for topic '{topic}': {str(e)}")

        # Remove duplicates based on article URL
        unique_articles = {article["url"]: article for article in all_articles}
        return list(unique_articles.values())

    def get_top_headlines(
        self,
        country: str = None,
        category: str = None,
        sources: List[str] = None,
        language: str = "en",
    ) -> List[Dict]:
        """
        Fetch top headlines for a specific country, category, or sources.

        Args:
            country: Country code (e.g., 'us', 'gb') for headlines
            category: News category (e.g., 'business', 'sports')
            sources: List of specific news sources
            language: Language of news articles

        Returns:
            List of top headlines
        """
        try:
            response = self.api.get_top_headlines(
                country=country,
                category=category,
                sources=",".join(sources) if sources else None,
                language=language,
            )

            if response["status"] == "ok":
                return response["articles"]
            else:
                print(
                    f"Error fetching top headlines: {response.get('message', 'Unknown error')}"
                )
                return []

        except Exception as e:
            print(f"Error fetching top headlines: {str(e)}")
            return []


# Example usage
def get_personalized_news():
    """Fetch personalized news articles based on user preferences."""

    # Initialize the news fetcher
    news_fetcher = NewsFetcher(settings.NEWS_API_KEY)

    # Fetch personalized news
    return news_fetcher.get_personalized_news(
        topics=settings.NEWS_TOPICS,
        preferred_sources=settings.NEWS_SOURCES,
        days_back=1,
    )


def get_top_us_news():
    """Fetch top news headlines from the US."""

    # Initialize the news fetcher
    news_fetcher = NewsFetcher(settings.NEWS_API_KEY)

    # Fetch top US news
    return news_fetcher.get_top_headlines(
        country="us",
    )

# %%
news_fetcher = NewsFetcher(settings.NEWS_API_KEY)

# %%
def get_top_us_news_by_category():
    """Fetch top news headlines from the US for specific categories."""

    # Initialize the news fetcher
    news_fetcher = NewsFetcher(settings.NEWS_API_KEY)

    categories = [
        "business",
        "entertainment",
        "general",
        "health",
        "science",
        "sports",
        "technology",
    ]
    news_by_category = {}

    for category in categories:
        news_by_category[category] = news_fetcher.get_top_headlines(
            country="us",
            category=category,
        )

    return news_by_category


get_top_us_news_by_category()
# Out:
# {'business': [{'source': {'id': 'associated-press',
#     'name': 'Associated Press'},
#    'author': 'Aamer Madhani, Christopher Rugaber, Josh Boak',
#    'title': "Trump suggests he can remove Fed Chair Powell and says he's 'not happy' with him over interest rates - AP News",
#    'description': 'President Donald Trump has attacked Federal Reserve Chair Jerome Powell for not cutting interest rates. And Trump says he could fire Powell if he wanted to. Trump is renewing a threat from his first term and it could cause a major legal showdown over the cent…',
#    'url': 'https://apnews.com/article/trump-powell-federal-reserve-fed-termination-b6148c8048dda538a6ca3b5a270fd09e',
#    'urlToImage': 'https://dims.apnews.com/dims4/default/7ccb842/2147483647/strip/true/crop/3447x1939+0+183/resize/1440x810!/quality/90/?url=https%3A%2F%2Fassets.apnews.com%2F8c%2F62%2Feac00ffe42b668f64dbb1587c708%2Fd6484aa6d741473cad05519a2159b675',
#    'publishedAt': '2025-04-17T22:29:00Z',
#    'content': 'WASHINGTON (AP) President Donald Trump attacked Federal Reserve Chair Jerome Powell on Thursday for not cutting interest rates and said he could fire him if he wanted to, renewing a threat from his f… [+6506 chars]'},
#   {'source': {'id': 'politico', 'name': 'Politico'},
#    'author': 'Steven Overly',
#    'title': 'An expert breaks down Zuckerberg’s big week in court - Politico',
#    'description': 'Meta’s survival depends on what’s happening in Judge James Boasberg’s courtroom. Here’s what just went down.',
#    'url': 'https://www.politico.com/news/2025/04/17/an-expert-breaks-down-zuckerbergs-big-week-in-court-00297783',
#    'urlToImage': 'https://static.politico.com/9c/c3/c921404d4296b137c0ff1b319e9f/senate-judiciary-committee-21084.jpg',
#    'publishedAt': '2025-04-17T21:45:08Z',
#    'content': 'Losing the high-stakes lawsuit, which was brought by the Federal Trade Commission, could ultimately lead to the Silicon Valley behemoth being forced to cleave off Instagram and WhatsApp a complex and… [+5667 chars]'},
#   {'source': {'id': 'axios', 'name': 'Axios'},
#    'author': 'Felix Salmon, Jacque Schrag',
#    'title': "The Dow's Thursday tumble, explained - Axios",
#    'description': 'The fall on Thursday represents the largest point impact for the DJIA on record.',
#    'url': 'https://www.axios.com/2025/04/17/unh-stock-united-healthcare-dow-jones',
#    'urlToImage': 'https://images.axios.com/sWel3-EhNfueVqudcPcFZm8MxDw=/0x0:1344x756/1366x768/2025/04/17/1744922047261.png',
#    'publishedAt': '2025-04-17T21:36:50Z',
#    'content': 'The Dow Jones Industrial Average fell 527 points on Thursday, despite the fact that 20 of its 30 components actually rose in price. The culprit: UnitedHealth Group, whose $131 fall was singlehandedly… [+777 chars]'},
#   {'source': {'id': None, 'name': 'Investopedia'},
#    'author': 'Colin Laidley',
#    'title': "UnitedHealth Loses $120 Billion in Value on Stock's Worst Day Since 1998 - Investopedia",
#    'description': 'UnitedHealth Group stock had one of its worst days ever on Thursday after the healthcare giant unexpectedly cut its profit forecast for the year.',
#    'url': 'https://www.investopedia.com/unitedhealth-stock-loses-usd120-billion-in-value-worst-day-since-1998-unh-11717480',
#    'urlToImage': 'https://www.investopedia.com/thmb/HKnsgEQk6BX8VzD4VLgaKGzZGDk=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/GettyImages-2187619709-ce1f67265b7141d7b27c63188d496024.jpg',
#    'publishedAt': '2025-04-17T21:08:41Z',
#    'content': 'UnitedHealth Group (UNH) stock had one of its worst days ever on Thursday after the healthcare giant unexpectedly cut its profit forecast for the year.\xa0\r\nUnitedHealth stock fell more than 22% on Thur… [+1954 chars]'},
#   {'source': {'id': None, 'name': 'NPR'},
#    'author': '',
#    'title': 'How tariffs could impact the availability of baby products - NPR',
#    'description': "NPR's Mary Louise Kelly speaks with Steven Dunn founder and CEO of Munchkin a U.S.-based company selling lifestyle products for mothers, babies and children. Dunn has written an open letter to President Trump and Congress about how tariffs could harm his busi…",
#    'url': 'https://www.npr.org/2025/04/17/nx-s1-5366723/tariffs-impact-baby-products',
#    'urlToImage': 'https://npr.brightspotcdn.com/dims3/default/strip/false/crop/4800x2700+0+88/resize/1400/quality/100/format/jpeg/?url=http%3A%2F%2Fnpr-brightspot.s3.amazonaws.com%2F15%2F7d%2F76ac42bc441ea11c432389fc9649%2Fgettyimages-1235018205.jpg',
#    'publishedAt': '2025-04-17T20:30:00Z',
#    'content': "If you have or have had small children, chances are, you're familiar with Munchkin products. The company manufactures everything from sippy cups to bath toys, breast pumps to baby gates. Munchkin fou… [+4707 chars]"},
#   {'source': {'id': 'bloomberg', 'name': 'Bloomberg'},
#    'author': 'Bailey Lipschultz, Esha Dey, Michael Mackenzie',
#    'title': 'Beneath Market’s Uneasy Calm, Dread Runs Deep Across Wall Street - Bloomberg.com',
#    'description': 'It was an unexpected, if improbable relief. The panic unleashed by Donald Trump’s trade war, which convulsed financial markets around the globe and sowed doubts about America’s standing in the world, died down nearly as quickly as it began.',
#    'url': 'https://www.bloomberg.com/news/articles/2025-04-17/beneath-market-s-uneasy-calm-dread-runs-deep-across-wall-street',
#    'urlToImage': 'https://assets.bwbx.io/images/users/iqjWHBFdfxIU/itEvyiX3hsRk/v1/1200x800.jpg',
#    'publishedAt': '2025-04-17T20:11:23Z',
#    'content': 'It was an unexpected, if improbable relief. The panic unleashed by Donald Trumps trade war, which convulsed financial markets around the globe and sowed doubts about Americas standing in the world, d… [+415 chars]'},
#   {'source': {'id': None, 'name': 'Variety'},
#    'author': 'Todd Spangler',
#    'title': 'Netflix Q1 Results Top Expectations as Streamer Stops Reporting Subscriber Counts - Variety',
#    'description': 'Netflix beat Wall Street financial estimates for Q1 2025, the first quarter it is no longer reporting subscriber counts.',
#    'url': 'https://variety.com/2025/tv/news/netflix-q1-2025-earnings-financial-results-subscriber-counts-1236371830/',
#    'urlToImage': 'https://variety.com/wp-content/uploads/2025/04/Cristin-Milioti-Black-Mirror.png?w=1000&h=563&crop=1',
#    'publishedAt': '2025-04-17T20:03:00Z',
#    'content': 'Netflix is no longer reporting number of subscribers on a quarterly basis. But it’s still motoring with a hot growth engine, delivering financial results for the first quarter of 2025 that topped Wal… [+3570 chars]'},
#   {'source': {'id': None, 'name': 'TheStreet'},
#    'author': 'TheStreet',
#    'title': 'Temu quietly makes drastic decision as consumers switch gears - TheStreet',
#    'description': None,
#    'url': 'https://www.thestreet.com/retail/temu-quietly-makes-drastic-decision-as-consumers-switch-gears',
#    'urlToImage': None,
#    'publishedAt': '2025-04-17T19:07:00Z',
#    'content': None},
#   {'source': {'id': None, 'name': 'Electrek'},
#    'author': 'Michelle Lewis',
#    'title': 'Trump admin halts $5 billion NY offshore wind project mid-build - Electrek',
#    'description': "In its most aggressive attack against offshore wind yet, the Trump administration halted the $5 billion Empire Wind 1 off New York's coast.",
#    'url': 'http://electrek.co/2025/04/17/trump-admin-ny-offshore-wind-mid-build/',
#    'urlToImage': 'https://i0.wp.com/electrek.co/wp-content/uploads/sites/3/2025/01/South-Brooklyn-Marine-Terminal-Equinor-Empire-Wind-1.jpg?resize=1200%2C628&quality=82&strip=all&ssl=1',
#    'publishedAt': '2025-04-17T19:01:00Z',
#    'content': 'Photo: Equinor\r\nIn its most aggressive attack against offshore wind yet, the Trump administration halted the $5 billion Empire Wind 1, already under construction off New Yorks coast.\r\nNorwegian devel… [+3724 chars]'},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Kyle Wiggers',
#    'title': 'Google’s latest AI model report lacks key safety details, experts say - TechCrunch',
#    'description': "The technical report for Google's latest AI model, Gemini 2.5 Pro, lacks key safety details, according to experts.",
#    'url': 'https://techcrunch.com/2025/04/17/googles-latest-ai-model-report-lacks-key-safety-details-experts-say/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2025/03/GettyImages-2169339854.jpg?resize=1200,857',
#    'publishedAt': '2025-04-17T18:53:20Z',
#    'content': 'On Thursday, weeks after launching its most powerful AI model yet, Gemini 2.5 Pro, Google published a technical report showing the results of its internal safety evaluations. However, the report is l… [+3708 chars]'},
#   {'source': {'id': 'associated-press', 'name': 'Associated Press'},
#    'author': "Anne D'Innocenzio",
#    'title': "Al Sharpton calls meeting with Target's CEO amid DEI backlash 'very constructive and candid' - AP News",
#    'description': 'Target’s chief executive officer has met with the Rev. Al Sharpton, whose civil rights organization has encouraged consumers to avoid U.S. retailers that scaled backed their diversity, equity and inclusion initiatives. In a statement issued by his National Ac…',
#    'url': 'https://apnews.com/article/target-al-sharpton-dei-520dbc23cd668b57b3bfef76d1bc7cdd',
#    'urlToImage': 'https://dims.apnews.com/dims4/default/f54af9b/2147483647/strip/true/crop/4000x2250+0+208/resize/1440x810!/quality/90/?url=https%3A%2F%2Fassets.apnews.com%2F3e%2F79%2F4f6133e745f5b8b7ee9b87782210%2F99e36d9f00b640318cb2ad1efe06aecd',
#    'publishedAt': '2025-04-17T18:03:00Z',
#    'content': 'NEW YORK (AP) Targets chief executive officer met Thursday with the Rev. Al Sharpton, whose civil rights organization has encouraged consumers to avoid U.S. retailers that scaled backed their diversi… [+2773 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Ash Parrish',
#    'title': 'Discord gets sued for allegedly violating child safety laws - The Verge',
#    'description': 'The state of New Jersey has filed suit against Discord for allegedly deceiving consumers that it does enough to protect young users.',
#    'url': 'https://www.theverge.com/news/650849/discord-gets-sued-for-allegedly-violating-child-safety-laws',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2025/03/acastro_STK062_01.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#    'publishedAt': '2025-04-17T17:04:12Z',
#    'content': 'The suit brought by the state of New Jersey is the first state action against the app.\r\nThe suit brought by the state of New Jersey is the first state action against the app.\r\nThe state of New Jersey… [+2088 chars]'},
#   {'source': {'id': None, 'name': 'CNBC'},
#    'author': 'Hugh Son',
#    'title': 'American Express’s wealthy cardholders are mostly untouched by tariff jitters - CNBC',
#    'description': "American Express results show that the company's wealthier customers may insulate it somewhat from concerns that tariffs and stubborn inflation have caused.",
#    'url': 'https://www.cnbc.com/2025/04/17/american-express-cardholders-still-spending-despite-trump-tariffs.html',
#    'urlToImage': 'https://image.cnbcfm.com/api/v1/image/108133451-1744905519290-gettyimages-159318207-72840091.jpeg?v=1744905562&w=1920&h=1080',
#    'publishedAt': '2025-04-17T16:47:10Z',
#    'content': "American Express's affluent cardmembers are showing few signs of curbing their spending, and younger customers drove growth in first-quarter transaction volumes, Chief Financial Officer\xa0Christophe Le… [+2430 chars]"},
#   {'source': {'id': None, 'name': 'Resiclubanalytics.com'},
#    'author': '',
#    'title': 'Zillow turns housing bear—just look at its updated 2025 forecast - ResiClub',
#    'description': 'Zillow projects that U.S. home prices will fall -1.7% between March 2025 and March 2026. Last month, Zillow economists still thought U.S. home prices would rise this year.',
#    'url': 'https://www.resiclubanalytics.com/p/zillow-turns-housing-bear-just-look-at-its-updated-2025-forecast',
#    'urlToImage': 'https://beehiiv-images-production.s3.amazonaws.com/uploads/asset/file/5e2eba3d-41ef-477f-9fc1-d969bacb32bf/Screenshot_2025-04-17_at_2.45.42_AM.png?t=1744874070',
#    'publishedAt': '2025-04-17T16:34:05Z',
#    'content': 'Todays letter is brought to you by Epum! \r\n ResiClub has a new data partnership with Epum, a real estate research lab which is focused on tracking commercial real estate projectsincluding single-fami… [+4723 chars]'},
#   {'source': {'id': None, 'name': 'BBC News'},
#    'author': None,
#    'title': "IMF: No global recession despite Donald Trump's tariffs - BBC",
#    'description': 'The international economic group predicts "notable markdowns, but not recession".',
#    'url': 'https://www.bbc.com/news/articles/ce3vk8z4p5lo',
#    'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/183b/live/014d7230-1ba2-11f0-82aa-a13f8272cbc5.jpg',
#    'publishedAt': '2025-04-17T16:02:58Z',
#    'content': 'Trade tariff uncertainty is "literally off the charts" but there will not be a global recession, the International Monetary Fund (IMF) has said.\r\nThe international economic group said in its forecast… [+1900 chars]'},
#   {'source': {'id': 'cnn', 'name': 'CNN'},
#    'author': 'Samantha Delouya',
#    'title': 'Mortgage rates climb to highest level in two months as Trump’s tariffs continue to rock markets - CNN',
#    'description': 'Springtime home shoppers may be feeling the impact of an intensifying trade war.',
#    'url': 'https://www.cnn.com/2025/04/17/economy/mortgage-rates-trade-war-tariffs/index.html',
#    'urlToImage': 'https://media.cnn.com/api/v1/images/stellar/prod/gettyimages-2206361094.jpg?c=16x9&q=w_800,c_fill',
#    'publishedAt': '2025-04-17T16:00:00Z',
#    'content': 'Springtime home shoppers may be feeling the impact of an intensifying trade war.\r\nThe average rate on a standard, 30-year fixed mortgage was 6.83% in the week ending April 17, up from 6.62% a week ag… [+1037 chars]'},
#   {'source': {'id': None, 'name': 'MarketWatch'},
#    'author': 'Joseph Adinolfi',
#    'title': "Dow on the cusp of first 'death cross' since November 2023 - MarketWatch",
#    'description': 'U.S. equities ended mostly lower Thursday in a holiday-shortened week, with Japan-U.S. trade talks in focus, UnitedHealth and criticism by President Trump of Fed Chair Powell.',
#    'url': 'https://www.marketwatch.com/livecoverage/stock-market-today-dow-s-p-and-nasdaq-in-line-for-higher-open-netflix-earnings-on-tap',
#    'urlToImage': 'https://mw3.wsj.net/mw5/content/logos/mw_logo_social.png',
#    'publishedAt': '2025-04-17T15:42:52Z',
#    'content': 'The Dow Jones Industrial Average was on the cusp of seeing a "death cross" on Thursday days after the S&amp;P 500 flashed the ominous technical signal.\r\nA death cross is a technical signal that occur… [+367 chars]'},
#   {'source': {'id': None, 'name': "Barron's"},
#    'author': "Barron's",
#    'title': "China Returns Boeing Jets. It’s a Headwind for the Stock. - Barron's",
#    'description': None,
#    'url': 'https://www.barrons.com/articles/boeing-stock-price-china-jets-c2b1bef2',
#    'urlToImage': None,
#    'publishedAt': '2025-04-17T15:18:00Z',
#    'content': None}],
#  'entertainment': [{'source': {'id': 'associated-press',
#     'name': 'Associated Press'},
#    'author': None,
#    'title': 'Haley Joel Osment charged with cocaine possession and being drunk in public - AP News',
#    'description': 'Oscar-nominated actor Haley Joel Osment has been charged with public intoxication and cocaine possession after his arrest earlier this month at a Northern California ski resort. The Mono County District Attorney’s office announced the misdemeanor charges Thur…',
#    'url': 'https://apnews.com/article/haley-joel-osment-arrest-f8bb94aa134400b30c44fb821dabdc6f',
#    'urlToImage': 'https://dims.apnews.com/dims4/default/a589a54/2147483647/strip/true/crop/4000x2250+0+208/resize/1440x810!/quality/90/?url=https%3A%2F%2Fassets.apnews.com%2Fa0%2Fbd%2F25dcf4179cdd74daadc0c5338e7c%2F758382d8eb524a60a349b68018fe5412',
#    'publishedAt': '2025-04-17T22:42:00Z',
#    'content': 'MAMMOTH LAKES, Calif. (AP) Oscar-nominated actor Haley Joel Osment has been charged with public intoxication and cocaine possession after his arrest earlier this month at a Northern California ski re… [+1136 chars]'},
#   {'source': {'id': None, 'name': 'Variety'},
#    'author': 'Zack Sharf',
#    'title': 'Wendy’s Says It ‘Has a Ton of Respect for Katy Perry’ After Posting ‘Can We Send Her Back’ to Space; Fast Food Chain Stops Short of Apologizing - Variety',
#    'description': "Wendy's says it has respect for Katy Perry but stopped short of apologizing to her after posting about wanting to send her back to space.",
#    'url': 'https://variety.com/2025/music/news/wendys-katy-perry-space-tweet-apologi-1236371955/',
#    'urlToImage': 'https://variety.com/wp-content/uploads/2025/04/wendys.jpg?w=1000&h=563&crop=1',
#    'publishedAt': '2025-04-17T20:32:00Z',
#    'content': 'Wendy’s has issued a statement to People magazine amid the buzz around its anti-Katy Perry post on X that asked if the singer can go back to space (aka get off Earth). The fast food chain went viral … [+2029 chars]'},
#   {'source': {'id': None, 'name': 'Deadline'},
#    'author': "Anthony D'Alessandro",
#    'title': '‘Daredevil: Born Again’ Season 2 Eyes Spring 2026 Premiere - Deadline',
#    'description': 'Daredevil: Born Again showrunner Dario Scardapene said Season 2 of the Disney+/Marvel series will premiere in March 2026.',
#    'url': 'http://deadline.com/2025/04/daredevil-born-again-season-2-premiere-date-1236371248/',
#    'urlToImage': 'https://deadline.com/wp-content/uploads/2025/04/BOF2440_109_comp_FLK_v0003.1499_R_f65275.jpg?w=1024',
#    'publishedAt': '2025-04-17T20:28:00Z',
#    'content': 'Daredevil: Born Againshowrunner Dario Scardapene recently took to Instagram to thank his teams for the Season 1 finale and also to tease that Season 2 of the Disney+/Marvel Studios series will premie… [+1257 chars]'},
#   {'source': {'id': None, 'name': 'Page Six'},
#    'author': 'Leah Bitsky',
#    'title': "Arnold Schwarzenegger's son Christopher shows off his massive weight loss in rare sibling photo - Page Six",
#    'description': 'Christopher appeared slimmed-down while hanging with his siblings, Katherine Schwarzenegger, Christina Schwarzenegger and Patrick Schwarzenegger.',
#    'url': 'https://pagesix.com/2025/04/17/celebrity-news/arnold-schwarzeneggers-son-christopher-shows-off-his-massive-weight-loss-in-rare-sibling-photo/',
#    'urlToImage': 'https://pagesix.com/wp-content/uploads/sites/3/2025/04/chris-s-weightloss.jpg?quality=75&strip=all&w=1024',
#    'publishedAt': '2025-04-17T20:05:00Z',
#    'content': 'He and his bodybuilder father could be “Twins.”\r\nArnold Schwarzenegger’s son Christopher flaunted his inspiring body transformation in a rare photo with his siblings.\r\nChristopher, 27, appeared slimm… [+2951 chars]'},
#   {'source': {'id': None, 'name': 'Deadline'},
#    'author': 'Nellie Andreeva',
#    'title': '‘Clueless’ Series Starring Alicia Silverstone In Works At Peacock - Deadline',
#    'description': 'A Clueless TV series with Silverstone attached to star has landed at Peacock for development. It is written by Josh Shwartz and Stephanie Savage.',
#    'url': 'http://deadline.com/2025/04/clueless-tv-series-alicia-silverstone-cher-peacock-1236371097/',
#    'urlToImage': 'https://deadline.com/wp-content/uploads/2025/04/Clueless_18e020.jpg?w=1024',
#    'publishedAt': '2025-04-17T20:00:00Z',
#    'content': 'As if! had been the response to fans’ wishes for a Clueless followup with Alicia Silverstone as Cher — until now. \r\nA Clueless TV series with Silverstone attached to star and executive produce has la… [+2720 chars]'},
#   {'source': {'id': None, 'name': 'Hollywood Reporter'},
#    'author': 'Tony Maglio',
#    'title': '‘Pacific Rim’ Series Lands at Amazon - The Hollywood Reporter',
#    'description': 'More fighting robots are on the way, courtesy of Legendary.',
#    'url': 'http://www.hollywoodreporter.com/tv/tv-news/pacific-rim-tv-series-amazon-prime-video-1236194158/',
#    'urlToImage': 'https://www.hollywoodreporter.com/wp-content/uploads/2025/04/MCDPARI_EC139-H-2025.jpg?w=1296&h=730&crop=1',
#    'publishedAt': '2025-04-17T19:16:43Z',
#    'content': 'Legendary‘s Pacific Rim series has landed at Amazon MGM Studios. The two studios will adapt the IP together (with Legendary in first position) for Amazon’s Prime Video streaming service.\r\nThe Pacific… [+2078 chars]'},
#   {'source': {'id': None, 'name': 'HuffPost'},
#    'author': 'Marco Margaritoff',
#    'title': '‘Mrs. Doubtfire’ Actor Shares 1 Heartbreaking Tip From Robin Williams: ‘I’ll Never Forget It’ - HuffPost',
#    'description': 'Matthew Lawrence shared that the late comedian once gave him some invaluable advice.',
#    'url': 'https://www.huffpost.com/entry/matthew-lawrence-robin-williams-advice-mrs-doubtfire_n_6801172fe4b0f92ccce1566b',
#    'urlToImage': 'https://img.huffingtonpost.com/asset/68013c711500001600cd615f.jpeg?cache=89D1RXhbGH&ops=1200_630',
#    'publishedAt': '2025-04-17T18:35:26Z',
#    'content': 'Matthew Lawrence says hell never forget the advice of his late co-star Robin Williams.\r\nThe former child actor was only 12 years old when he starred opposite Williams in Mrs. Doubtfire, the 1993 clas… [+3733 chars]'},
#   {'source': {'id': None, 'name': 'Page Six'},
#    'author': 'Nicki Gostin',
#    'title': 'NYC restaurateur Keith McNally names ‘incredibly rude’ music icon who made waitress cry - Page Six',
#    'description': 'McNally calls out the music icon for reducing a waitress to tears because the server had forgotten to put bread on the table.',
#    'url': 'https://pagesix.com/2025/04/17/celebrity-news/keith-mcnally-names-incredibly-rude-music-icon-who-made-waitress-cry/',
#    'urlToImage': 'https://pagesix.com/wp-content/uploads/sites/3/2025/04/102877770.jpg?quality=75&strip=all&w=1024',
#    'publishedAt': '2025-04-17T18:22:00Z',
#    'content': 'Famed NYC restaurateur Keith McNally is spilling the beans on an “incredibly rude” music icon who once allegedly reduced a waitress to tears.\r\nIn his upcoming book, “Regret Almost Everything, McNally… [+3279 chars]'},
#   {'source': {'id': None, 'name': 'Hollywood Reporter'},
#    'author': 'Mike Barnes',
#    'title': 'Patrick Adiarte, Actor in ‘The King and I,’ ‘Flower Drum Song’ and ‘M*A*S*H,’ Dies at 82 - The Hollywood Reporter',
#    'description': 'A native of the Philippines — he and his family were imprisoned during World War II — he guest-starred on ‘The Brady Bunch’ and, mentored by Gene Kelly, danced on ‘Hullabaloo.’',
#    'url': 'http://www.hollywoodreporter.com/movies/movie-news/patrick-adiarte-dead-mash-king-and-i-flower-drum-song-1236194077/',
#    'urlToImage': 'https://www.hollywoodreporter.com/wp-content/uploads/2025/04/Patrick-Adiarte-Obit-Template-Headshot-Everett-H-2025.jpg?w=1296&h=730&crop=1',
#    'publishedAt': '2025-04-17T18:01:39Z',
#    'content': 'Patrick Adiarte, the Philippines-born dancer and actor who appeared in The King and I and Flower Drum Song on Broadway and the big screen and had a recurring role on M*A*S*H, has died. He was 82.\r\nAd… [+3894 chars]'},
#   {'source': {'id': None, 'name': 'Salon'},
#    'author': None,
#    'title': "Blue Origin's all-woman space flight made history, but not in the way it's being sold - Salon.com",
#    'description': "The unifying message of Monday's all-woman rocket flight is that for now, space belongs to the hot and rich",
#    'url': 'https://www.salon.com/2025/04/17/blue-origins-all-woman-space-flight-made-history-but-not-in-the-way-its-promoting/',
#    'urlToImage': 'https://mediaproxy.salon.com/width/1200/https://media2.salon.com/2025/04/blue-origin-ns-31_crewjpg.jpg',
#    'publishedAt': '2025-04-17T17:29:00Z',
#    'content': None},
#   {'source': {'id': None, 'name': 'Variety'},
#    'author': 'Elsa Keslassy',
#    'title': "'Emily in Paris' Season 5 to Start Filming in Rome in May - Variety",
#    'description': "Lily Collins' Emily Cooper will be living the dolce vita in Rome in the much-anticipated fifth season of Netflix's 'Emily in Paris.'",
#    'url': 'https://variety.com/2025/tv/filming-locations/emily-in-paris-season-5-filming-in-rome-may-1236371462/',
#    'urlToImage': 'https://variety.com/wp-content/uploads/2025/04/AAAAQRY44OC9a5MeYgebU7bTuStkj8PaSLsLfaiBOsCVXowacr00zShwNCPsSLa5QxVU7qeaVMvmupa8yMzlbhZALwxy4nZ1iFcKUqjuk9xzbyS5cwzBSYktoosqu4b9hA5qKS8tBMHDwXasPQWhmmni7b6qMNo.jpg?w=1000&h=563&crop=1',
#    'publishedAt': '2025-04-17T16:16:00Z',
#    'content': 'Lily Collins‘ Emily Cooper will be living the dolce vita in Rome with her Italian beau Marcello in the much-anticipated fifth season of Netflix‘s “Emily in Paris.” Or at least some of it. The new sea… [+3523 chars]'},
#   {'source': {'id': None, 'name': 'Pitchfork'},
#    'author': 'Nina Corcoran',
#    'title': 'Coachella 2025 Weekend 2 Lineup and Schedule: All the Set Times You Need to Know - Pitchfork',
#    'description': 'Ed Sheeran returns as a last-minute addition, joining Lady Gaga, Green Day, Charli XCX, Kraftwerk, and more',
#    'url': 'https://pitchfork.com/news/coachella-2025-weekend-2-lineup-and-schedule-all-the-set-times-you-need-to-know/',
#    'urlToImage': 'https://media.pitchfork.com/photos/6801157a84c6efee1e2c2ef3/16:9/w_1280,c_limit/GettyImages-484439149.jpg',
#    'publishedAt': '2025-04-17T16:05:00Z',
#    'content': 'The Original Misfits (11:20, Outdoor Theatre)Above &amp; Beyond (9:45, Outdoor Theatre)Clairo (8:15, Outdoor Theatre)Gustavo Dudamel &amp; LA Phil (6:25, Outdoor Theatre)Japanese Breakfast (5:05, Out… [+2607 chars]'},
#   {'source': {'id': None, 'name': 'NPR'},
#    'author': '',
#    'title': "'Sinners' gives Michael B. Jordan two roles of a lifetime - NPR",
#    'description': 'In Sinners, Ryan Coogler creates a bold original vision, and Michael B. Jordan is at the top of his game.',
#    'url': 'https://www.npr.org/2025/04/17/nx-s1-5366509/sinners-review-michael-b-jordan',
#    'urlToImage': 'https://npr.brightspotcdn.com/dims3/default/strip/false/crop/2567x1444+764+0/resize/1400/quality/100/format/jpeg/?url=http%3A%2F%2Fnpr-brightspot.s3.amazonaws.com%2F9b%2F1a%2F1bd8c816439099d14368276b70ce%2Frev-1-grc-trl2-001r-high-res-jpeg.jpeg',
#    'publishedAt': '2025-04-17T16:00:00Z',
#    'content': 'Nothing in life is free, but many things cannot be paid for in money or material goods. Faustian legend persists because of its cross-cultural appeal an understanding that to exist in this world is t… [+6506 chars]'},
#   {'source': {'id': None, 'name': 'WWD'},
#    'author': 'Miles Socha',
#    'title': 'Anderson to Show First Dior Men’s Collection in June - WWD',
#    'description': "Jonathan Anderson is Kim Jones' successor at Dior Men and will present his first collection in June, Bernard Arnault announced at the LVMH shareholders meeting.",
#    'url': 'http://wwd.com/fashion-news/designer-luxury/jonathan-anderson-dior-men-designer-1237091199/',
#    'urlToImage': 'https://wwd.com/wp-content/uploads/2025/04/JONATHAN-ANDERSON-DAVID-SIMS-courtesy.jpg?crop=137px%2C177px%2C1726px%2C967px&resize=1000%2C563',
#    'publishedAt': '2025-04-17T15:27:19Z',
#    'content': 'PARIS – Bernard Arnault surprised the fashion world – and apparently everybody at LVMH – by announcing to shareholders Thursday that star designer Jonathan Anderson has succeeded Kim Jones as Dior’s … [+7145 chars]'},
#   {'source': {'id': 'entertainment-weekly', 'name': 'Entertainment Weekly'},
#    'author': 'Joey Nolfi',
#    'title': "Kelly Ripa calls out “Live” audience member who interrupted Christopher Meloni interview: 'We'll handle the questions' - Yahoo News UK",
#    'description': 'An inquisitive "Live" audience member shouted out a question for Meloni about a secluded vacation spot he visited with his wife.',
#    'url': 'https://ew.com/kelly-ripa-calls-out-live-audience-member-christopher-meloni-interview-11717053',
#    'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/3e7OJOz0B4Od_JBL0Oh_4A--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD04MDA-/https://media.zenfs.com/en/entertainment_weekly_785/23beb7200ea524dffbd3cd915daf2b38',
#    'publishedAt': '2025-04-17T15:15:00Z',
#    'content': 'Key Points\r\n<ul><li>Kelly Ripa and Mark Consuelos welcomed Law &amp; Order star Christopher Meloni for an interview.\r\n</li><li>Meloni spoke about a secluded vacation destination in the Dominican Repu… [+2216 chars]'},
#   {'source': {'id': None, 'name': 'IndieWire'},
#    'author': 'Samantha Bergeson',
#    'title': '‘The Fantastic Four: First Steps’ New Trailer: Julia Garner’s Silver Surfer Offers a Warning to Earth’s Protectors - IndieWire',
#    'description': "'The Fantastic Four: First Steps' stars Pedro Pascal, Vanessa Kirby, and Julia Garner.",
#    'url': 'https://www.indiewire.com/news/trailers/the-fantastic-four-first-steps-new-trailer-1235116188/',
#    'urlToImage': 'https://www.indiewire.com/wp-content/uploads/2025/04/Screen-Shot-2025-04-17-at-10.24.51-AM.png?w=650',
#    'publishedAt': '2025-04-17T14:41:52Z',
#    'content': 'Julia Garner’s Silver Surfer, AKA Shalla-Bal, has been finally unveiled in the latest trailer for “The Fantastic Four: First Steps.” \r\nThe film, which stars Pedro Pascal, Ebon Moss-Bachrach, Vanessa … [+2381 chars]'},
#   {'source': {'id': None, 'name': 'The Cut'},
#    'author': 'Julia Reinstein',
#    'title': 'Michelle Trachtenberg Died of Diabetes Complications - The Cut',
#    'description': 'On Wednesday, New York medical examiners revealed that the ‘Gossip Girl’ star died from diabetes mellitus in February.',
#    'url': 'http://www.thecut.com/article/what-was-michelle-trachtenbergs-official-cause-of-death.html',
#    'urlToImage': 'https://pyxis.nymag.com/v1/imgs/693/617/933d3760402f49ac07a3a5435e5c176993-michelle-trachtenberg-2.1x.rsocial.w1200.jpg',
#    'publishedAt': '2025-04-17T14:26:32Z',
#    'content': 'In February, actor Michelle Trachtenberg was found dead in her midtown apartment at 39. On Wednesday, officials released her cause of death, ruling that she died from complications related to diabete… [+1221 chars]'},
#   {'source': {'id': 'the-wall-street-journal',
#     'name': 'The Wall Street Journal'},
#    'author': 'WSJ',
#    'title': 'Drake Says Kendrick Lamar’s Hit Super Bowl Performance Juiced Damages Owed - WSJ',
#    'description': None,
#    'url': 'https://www.wsj.com/business/media/drake-says-kendrick-lamars-hit-super-bowl-performance-juiced-damages-owed-044fe7eb',
#    'urlToImage': None,
#    'publishedAt': '2025-04-17T14:11:00Z',
#    'content': None},
#   {'source': {'id': None, 'name': 'Variety'},
#    'author': 'Nick Vivarelli',
#    'title': "Karla Sofía Gascón's Next Film: 'The Life Lift' With Vincent Gallo - Variety",
#    'description': "Karla Sofía Gascón has announced she will co-star with Vincent Gallo in thriller 'The Life Lift,' in which she is set to play both God and the devil.",
#    'url': 'https://variety.com/2025/film/global/karla-sofia-gascon-next-film-life-lift-vincent-gallo-1236371460/',
#    'urlToImage': 'https://variety.com/wp-content/uploads/2025/04/karla-vincent.jpg?w=1000&h=563&crop=1',
#    'publishedAt': '2025-04-17T13:57:00Z',
#    'content': '“Emilia Pérez” star Karla Sofía Gascón has set her first project after controversy erupted in January over her past offensive tweets. The Oscar nominee revealed that she will lead “The Life Lift,” a … [+3001 chars]'},
#   {'source': {'id': None, 'name': 'TVLine'},
#    'author': 'Claire Franken',
#    'title': 'What to Watch: Bosch Ends, XL Matlock Finale, Law & Order: OC Returns and More - TVLine',
#    'description': 'On TV this Thursday: Bosch goes off duty, Matlock airs its supersized finale and Law & Order: Organized Crime makes the leap to Peacock.',
#    'url': 'https://tvline.com/what-to-watch/bosch-legacy-series-finale-amazon-prime-video/',
#    'urlToImage': 'https://tvline.com/wp-content/uploads/2025/04/bosch-legacy-series-finale-renee-ballard-prime-video.jpg?w=650',
#    'publishedAt': '2025-04-17T13:20:59Z',
#    'content': 'To help you anticipate and navigate all that television has to offer across broadcast, cable and streaming, TVLine offers\xa0daily, weekly and monthly What to Watch digests, as well as an overview of\xa0ev… [+2581 chars]'}],
#  'general': [{'source': {'id': 'cnn', 'name': 'CNN'},
#    'author': 'Kara Scannell, Eric Levenson',
#    'title': 'Luigi Mangione indicted on federal charges in killing of UnitedHealthcare CEO - CNN',
#    'description': 'Luigi Mangione, the 26-year-old accused of fatally shooting UnitedHealthcare’s CEO on a Manhattan sidewalk last year, was indicted in federal court on charges of murder, stalking and a firearms offense.',
#    'url': 'https://www.cnn.com/2025/04/17/us/luigi-mangione-indicted-federal-charges/index.html',
#    'urlToImage': 'https://media.cnn.com/api/v1/images/stellar/prod/gettyimages-2200303302.jpg?c=16x9&q=w_800,c_fill',
#    'publishedAt': '2025-04-17T23:08:00Z',
#    'content': 'Luigi Mangione, the 26-year-old accused of fatally shooting UnitedHealthcares CEO on a Manhattan sidewalk last year, was indicted in federal court on charges of murder, stalking and a firearms offens… [+2927 chars]'},
#   {'source': {'id': None, 'name': 'NBCSports.com'},
#    'author': 'Charean Williams',
#    'title': 'Bills agree to terms with CB Tre’Davious White on a one-year deal - NBC Sports',
#    'description': "The Bills have agreed to a one-year deal worth up to $6.8 million with cornerback Tre'Davious White, Adam Schefter of ESPN reports.",
#    'url': 'https://www.nbcsports.com/nfl/profootballtalk/rumor-mill/news/bills-agree-to-terms-with-cb-tredavious-white-on-a-one-year-deal',
#    'urlToImage': 'https://nbcsports.brightspotcdn.com/dims4/default/00ff195/2147483647/strip/true/crop/2147x1208+0+177/resize/1440x810!/quality/90/?url=https%3A%2F%2Fnbc-sports-production-nbc-sports.s3.us-east-1.amazonaws.com%2Fbrightspot%2F7c%2F4e%2F836fd6984c92af119af39301d5cc%2Fhttps-delivery-gettyimages.com%2Fdownloads%2F1731522198',
#    'publishedAt': '2025-04-17T22:36:06Z',
#    'content': 'The Bills have agreed to a one-year deal worth up to $6.8 million with cornerback TreDavious White, Adam Schefter of ESPN reports.\r\nWhite returns to the team that made him a first-round pick in 2017.… [+358 chars]'},
#   {'source': {'id': 'cnn', 'name': 'CNN'},
#    'author': 'Abeer Salman, Tamar Michaelis, Mohammed Tawfeeq',
#    'title': 'Hamas rejects ceasefire offer as far-right Israeli lawmakers call for escalation in Gaza - CNN',
#    'description': 'Hamas has rejected the Israeli ceasefire offer presented earlier this week, according to a senior Hamas official, instead calling for a “comprehensive” proposal to end the war.',
#    'url': 'https://www.cnn.com/2025/04/17/middleeast/hamas-rejects-israeli-ceasefire-offer-intl-latam/index.html',
#    'urlToImage': 'https://media.cnn.com/api/v1/images/stellar/prod/gettyimages-2210067618.jpg?c=16x9&q=w_800,c_fill',
#    'publishedAt': '2025-04-17T22:10:00Z',
#    'content': 'Hamas has rejected the Israeli ceasefire offer presented earlier this week, according to a senior Hamas official, instead calling for a comprehensive proposal to end the war.\r\nThe official told CNN, … [+5501 chars]'},
#   {'source': {'id': 'axios', 'name': 'Axios'},
#    'author': 'Felix Salmon, Jacque Schrag',
#    'title': "The Dow's Thursday tumble, explained - Axios",
#    'description': 'The fall on Thursday represents the largest point impact for the DJIA on record.',
#    'url': 'https://www.axios.com/2025/04/17/unh-stock-united-healthcare-dow-jones',
#    'urlToImage': 'https://images.axios.com/sWel3-EhNfueVqudcPcFZm8MxDw=/0x0:1344x756/1366x768/2025/04/17/1744922047261.png',
#    'publishedAt': '2025-04-17T21:36:50Z',
#    'content': 'The Dow Jones Industrial Average fell 527 points on Thursday, despite the fact that 20 of its 30 components actually rose in price. The culprit: UnitedHealth Group, whose $131 fall was singlehandedly… [+777 chars]'},
#   {'source': {'id': 'associated-press', 'name': 'Associated Press'},
#    'author': 'Michael Kunzelman, Eric Tucker, Alanna Durkin Richer',
#    'title': 'Trump officials’ defiance over Abrego Garcia’s deportation is ‘shocking,’ appeals court says - AP News',
#    'description': 'A federal appeals court says it is “shocking” that The Trump administration claims it can’t do anything to free Kilmar Abrego Garcia from an El Salvador prison and return him to the U.S. A three-judge panel from the 4th U.S. Circuit Court of Appeals on Thursd…',
#    'url': 'https://apnews.com/article/abrego-garcia-trump-maryland-el-salvador-2090f0dd508bbc3d2f60845842af27b4',
#    'urlToImage': 'https://dims.apnews.com/dims4/default/0aca7d1/2147483647/strip/true/crop/6000x3375+0+312/resize/1440x810!/quality/90/?url=https%3A%2F%2Fassets.apnews.com%2F6f%2F26%2F51840e5ed136828d2845c3974d63%2Fa76685c0ca494bb3be86899cd908c3e3',
#    'publishedAt': '2025-04-17T21:24:00Z',
#    'content': 'WASHINGTON (AP) The Trump administrations claim that it cant do anything to free Kilmar Abrego Garcia from an El Salvador prison and return him to the U.S. should be shocking, a federal appeals court… [+5801 chars]'},
#   {'source': {'id': None, 'name': 'CBS Sports'},
#    'author': 'Chris Trapasso',
#    'title': '2025 NFL mock draft: Grades for every first-round pick, including AFC team trading up for Shedeur Sanders - CBS Sports',
#    'description': "CBS Sports' NFL draft experts determine which players are going where in next week's draft",
#    'url': 'https://www.cbssports.com/nfl/news/2025-nfl-mock-draft-grades-for-every-first-round-pick-including-afc-team-trading-up-for-shedeur-sanders/live/',
#    'urlToImage': 'https://sportshub.cbsistatic.com/i/r/2025/04/11/2381d89b-df5f-478f-b3f0-d5284b9339c5/thumbnail/1200x675/be3c440e4a3bf96c8241deab2cdb931e/shedeur-sanders-g.jpg',
#    'publishedAt': '2025-04-17T21:04:26Z',
#    'content': 'One week away from the 2025 NFL Draft means it\'s time for a comprehensive, multi-analyst event: a live seven-round mock draft courtesy of CBS Sports\'\xa0"With the First Pick" podcast.\r\nHere\'s how it wor… [+5299 chars]'},
#   {'source': {'id': 'abc-news', 'name': 'ABC News'},
#    'author': 'ABC News',
#    'title': 'FSU shooting latest: 2 dead, 6 injured; 20-year-old suspect in custody - ABC News',
#    'description': None,
#    'url': 'https://abcnews.go.com/US/active-shooter-reported-florida-state-university-fsu-alert/story?id\\\\u003d120911309',
#    'urlToImage': None,
#    'publishedAt': '2025-04-17T21:00:00Z',
#    'content': None},
#   {'source': {'id': None, 'name': 'Financial Times'},
#    'author': 'Claire Jones',
#    'title': 'Could Donald Trump fire Federal Reserve chair Jay Powell? - Financial Times',
#    'description': 'Ninety-year-old precedent known as Humphrey’s Executor is crucial guardrail protecting US central bank’s independence',
#    'url': 'https://www.ft.com/content/2c7302d3-ce64-438f-85e7-96375058ecad',
#    'urlToImage': 'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2Fc55d23ff-ea47-42f5-8ba0-c562de53f421.jpg?source=next-barrier-page',
#    'publishedAt': '2025-04-17T20:38:41Z',
#    'content': 'Join FT Edit\r\nOnly $49 a year\r\nGet 2 months free with an annual subscription at was $59.88now $49.\r\nAccess to eight surprising articles a day, hand-picked by FT editors. For seamless reading, access … [+127 chars]'},
#   {'source': {'id': 'abc-news', 'name': 'ABC News'},
#    'author': 'ABC News',
#    'title': 'Michigan reports first confirmed measles outbreak since 2019 - ABC News',
#    'description': None,
#    'url': 'https://abcnews.go.com/Health/michigan-reports-confirmed-measles-outbreak-2019/story?id\\\\u003d120920799',
#    'urlToImage': None,
#    'publishedAt': '2025-04-17T20:26:15Z',
#    'content': None},
#   {'source': {'id': None, 'name': 'Variety'},
#    'author': 'Todd Spangler',
#    'title': 'Netflix Q1 Results Top Expectations as Streamer Stops Reporting Subscriber Counts - Variety',
#    'description': 'Netflix beat Wall Street financial estimates for Q1 2025, the first quarter it is no longer reporting subscriber counts.',
#    'url': 'https://variety.com/2025/tv/news/netflix-q1-2025-earnings-financial-results-subscriber-counts-1236371830/',
#    'urlToImage': 'https://variety.com/wp-content/uploads/2025/04/Cristin-Milioti-Black-Mirror.png?w=1000&h=563&crop=1',
#    'publishedAt': '2025-04-17T20:03:00Z',
#    'content': 'Netflix is no longer reporting number of subscribers on a quarterly basis. But it’s still motoring with a hot growth engine, delivering financial results for the first quarter of 2025 that topped Wal… [+3570 chars]'},
#   {'source': {'id': None, 'name': 'State.gov'},
#    'author': None,
#    'title': 'Secretary Rubio’s Call with Russian Foreign Minister Sergey Lavrov - U.S. Department of State (.gov)',
#    'description': 'The below is attributable to Spokesperson Tammy Bruce: Secretary of State Marco Rubio spoke today with Russian Foreign Minister Sergey Lavrov. The Secretary conveyed to his Russian counterpart the same message the U.S. team communicated to the Ukrainian deleg…',
#    'url': 'https://www.state.gov/secretary-rubios-call-with-russian-foreign-minister-sergey-lavrov/',
#    'urlToImage': 'https://www.state.gov/wp-content/uploads/2025/01/Press_Release_Alabaster.png',
#    'publishedAt': '2025-04-17T19:26:23Z',
#    'content': 'The below is attributable to Spokesperson Tammy Bruce:\r\nSecretary of State Marco Rubio spoke today with Russian Foreign Minister Sergey Lavrov. The Secretary conveyed to his Russian counterpart the s… [+376 chars]'},
#   {'source': {'id': 'ars-technica', 'name': 'Ars Technica'},
#    'author': 'Ryan Whitwam',
#    'title': 'Gemini 2.5 Flash comes to the Gemini app as Google seeks to improve “dynamic thinking” - Ars Technica',
#    'description': 'Gemini 2.5 Flash is ready for you to try in the Gemini app, but it’s starting as a preview.',
#    'url': 'https://arstechnica.com/ai/2025/04/gemini-2-5-flash-comes-to-the-gemini-app-gives-developers-control-over-thinking/',
#    'urlToImage': 'https://cdn.arstechnica.net/wp-content/uploads/2025/03/Gemini-app-1152x648.jpg',
#    'publishedAt': '2025-04-17T19:06:17Z',
#    'content': None},
#   {'source': {'id': None, 'name': 'Forbes'},
#    'author': 'Genna Contino',
#    'title': 'Nearly Half Of Puerto Rico Still Without Power After All Its Power Plants Failed - Forbes',
#    'description': 'All of Puerto Rico’s power plants went out of service Wednesday afternoon, causing an island-wide blackout.',
#    'url': 'https://www.forbes.com/sites/gennacontino/2025/04/17/nearly-half-of-puerto-rico-still-without-power-after-all-its-power-plants-failed/',
#    'urlToImage': 'https://imageio.forbes.com/specials-images/imageserve/6800137f43ac4563da08a51e/0x0.jpg?format=jpg&height=900&width=1600&fit=bounds',
#    'publishedAt': '2025-04-17T18:55:41Z',
#    'content': 'Nearly 620,000 are still without power in Puerto Rico on Thursday, more than 24 hours after the entire island lost electricity when its power plants were knocked out of service, the latest breakdown … [+2441 chars]'},
#   {'source': {'id': None, 'name': 'Live Science'},
#    'author': 'Joanna Thompson',
#    'title': "Scientists may have finally found where the 'missing half' of the universe's matter is hiding - Live Science",
#    'description': 'About half of the non-dark matter in the universe cannot be accounted for by stars and galaxies alone. Now, scientists say previously undetected clouds of hydrogen gas could finally reveal it.',
#    'url': 'https://www.livescience.com/space/cosmology/scientists-may-have-finally-found-where-the-missing-half-of-the-universes-matter-is-hiding',
#    'urlToImage': 'https://cdn.mos.cms.futurecdn.net/fK37XAgvQwEGEpK3d5mJVF.jpg',
#    'publishedAt': '2025-04-17T18:53:37Z',
#    'content': "The universe's missing matter may have finally been found.\r\nAstronomers think regular matter — that is, the stuff that isn't dark matter\r\n — makes up about 15% of the universe's total mass. However, … [+3210 chars]"},
#   {'source': {'id': None, 'name': 'BBC News'},
#    'author': 'https://www.facebook.com/bbcnews',
#    'title': 'Menendez brothers appear in court via video link as resentencing hearing starts - BBC',
#    'description': 'Erik and Lyle Menendez were sentenced to life in prison for the murder of their parents in 1989.',
#    'url': 'https://www.bbc.com/news/live/c4g7zvv78n4t',
#    'urlToImage': 'https://ichef.bbci.co.uk/ace/branded_news/1200/cpsprodpb/5b69/live/705bde90-1ba8-11f0-b1b3-7358f8d35a35.jpg',
#    'publishedAt': '2025-04-17T18:33:45Z',
#    'content': "Image caption, Former LA District Attorney George Gascon supported the Menendez brother's resentencing bid, but critics claim the move was politically motivated\r\nAlmost three decades after the Menend… [+1057 chars]"},
#   {'source': {'id': None, 'name': 'NASA'},
#    'author': 'Tara Friesen',
#    'title': 'NASA’s Curiosity Rover May Have Solved Mars’ Missing Carbonate Mystery - NASA (.gov)',
#    'description': 'Researchers have long believed that Mars once had a thick, carbon dioxide-rich atmosphere and liquid water on the planet’s surface. That carbon dioxide and',
#    'url': 'https://www.nasa.gov/centers-and-facilities/ames/nasas-curiosity-rover-may-have-solved-mars-missing-carbonate-mystery/',
#    'urlToImage': 'https://www.nasa.gov/wp-content/uploads/2025/04/1-pia26554-curiosity-surveys-the-ubajara-sampling-site-4-figure-a.jpg',
#    'publishedAt': '2025-04-17T18:03:53Z',
#    'content': 'New findings from NASAs Curiosity Mars rover could provide an answer to the mystery of what happened to the planets ancient atmosphere and how Mars has evolved over time.\r\nResearchers have long belie… [+2930 chars]'},
#   {'source': {'id': 'bleacher-report', 'name': 'Bleacher Report'},
#    'author': 'Adam Wells',
#    'title': "Aaron Rodgers Told NFL Teams He'd Play for $10M Contract, Retirement is 'Possibility' - Bleacher Report",
#    'description': None,
#    'url': 'https://bleacherreport.com/articles/25187499-aaron-rodgers-told-nfl-teams-hed-play-10m-contract-retirement-possibility',
#    'urlToImage': 'https://gsp-image-cdn.wmsports.io/cms/prod/bleacher-report/ap_images/e0ae76237f7546e09ddf913d1cff4e79/Dolphins_Jets_Football_07878_3402x1914_(0,0).jpg?w=3800&h=2000',
#    'publishedAt': '2025-04-17T18:00:00Z',
#    'content': "In his first public comments since being released by the New York Jets in March, Aaron Rodgers is still contemplating his future. \r\nAppearing on Thursday's episode of The Pat McAfee Show, Rodgers \r\ns… [+2250 chars]"}],
#  'health': [{'source': {'id': None, 'name': 'SciTechDaily'},
#    'author': None,
#    'title': 'Eating Too Much Salt Could Increase Your Risk of Obesity by Over 330% - SciTechDaily',
#    'description': 'High sodium intake is linked to greater obesity risk, particularly in women, even when it comes from everyday foods. New research to be presented at the European Congress on Obesity (ECO 2025), taking place in Malaga, Spain (11–14 May), highlights a link betw…',
#    'url': 'https://scitechdaily.com/eating-too-much-salt-could-increase-your-risk-of-obesity-by-over-330/',
#    'urlToImage': 'https://scitechdaily.com/images/Sprinkling-Salt-on-Table-Concept.jpg',
#    'publishedAt': '2025-04-17T21:52:21Z',
#    'content': 'High sodium intake is linked to a greater risk of general and abdominal obesity, with strong associations found in both men and women. Finnish researchers urge dietary reform and more research into t… [+7988 chars]'},
#   {'source': {'id': None, 'name': 'syracuse.com'},
#    'author': 'Kelly Corbett | kcorbett@syracuse.com',
#    'title': 'Ingredient found in common cooking oils may be linked to aggressive form of cancer, says new study - Syracuse.com',
#    'description': 'The study, published last month, was led by researchers at Weill Cornell Medicine.',
#    'url': 'https://www.syracuse.com/health/2025/04/ingredient-found-in-common-cooking-oils-may-be-linked-to-aggressive-form-of-cancer-says-new-study.html',
#    'urlToImage': 'https://www.syracuse.com/resizer/v2/FLF3XN2EZFGOLIRC3CGDKUIHNM.jpg?auth=05b64924d999b231990d78d667ec71327732de6d5d4ef38b32f474ac1846b9d9&width=1280&quality=90',
#    'publishedAt': '2025-04-17T21:05:00Z',
# ...
#   {'source': {'id': None, 'name': 'CBS Sports'},
#    'author': '',
#    'title': 'College basketball rankings: Florida into top 10 as Xaivian Lee addition gives backcourt much-needed boost - CBS Sports',
#    'description': 'Lee averaged 16.9 points per games last season for Princeton',
#    'url': 'https://www.cbssports.com/college-basketball/news/college-basketball-rankings-florida-into-top-10-as-xaivian-lee-addition-gives-backcourt-much-needed-boost/',
#    'urlToImage': 'https://sportshub.cbsistatic.com/i/r/2025/04/17/8745211a-63c0-4437-8137-f76112aa6d55/thumbnail/1200x675/65b9a38f4c15ec20e52d8e06ea149585/lee-top-25.jpg',
#    'publishedAt': '2025-04-17T17:33:00Z',
#    'content': "Florida is expected to return, among others, Alex Condon, Reuben Chinyelu and Thomas Haugh three veterans, all 6-foot-9 or taller, who played big roles in the Gators' run through the 2025 NCAA Tourna… [+15522 chars]"}],
#  'technology': [{'source': {'id': None, 'name': 'CNET'},
#    'author': 'See full bio',
#    'title': "Marvel Rivals' New Costume Customization Is Fairly Priced, but There's a Problem - CNET",
#    'description': "A couple dollars isn't much to pay for in-depth skin customization, but you can't spend your existing Units on the new feature.",
#    'url': 'https://www.cnet.com/tech/gaming/marvel-rivals-new-costume-customization-is-fairly-priced-but-theres-a-problem/',
#    'urlToImage': 'https://www.cnet.com/a/img/resize/32a286b23d03e490e44f44c209f04bff464f29d3/hub/2025/04/17/61e49ce2-06e3-4514-bc86-fd3573c17868/marvel-rivals-costume-customization.jpg?auto=webp&fit=crop&height=675&width=1200',
#    'publishedAt': '2025-04-17T22:43:00Z',
#    'content': "Marvel Rivals' latest Season 2 feature is targeted at all the fashionistas out there. Costume customization lets players change the color palette of their skin, creating a new in-game look that suits… [+4776 chars]"},
#   {'source': {'id': 'ars-technica', 'name': 'Ars Technica'},
#    'author': 'Benj Edwards',
#    'title': 'Cursor AI support bot invents fake policy and triggers user uproar - Ars Technica',
#    'description': 'Frustrated software developer believed AI-generated message came from human support rep.',
#    'url': 'https://arstechnica.com/ai/2025/04/cursor-ai-support-bot-invents-fake-policy-and-triggers-user-uproar/',
#    'urlToImage': 'https://cdn.arstechnica.net/wp-content/uploads/2025/04/telephone_robot_2-1152x648.jpg',
#    'publishedAt': '2025-04-17T22:42:23Z',
#    'content': None},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Antonio G. Di Benedetto',
#    'title': 'Razer has quietly un-paused some laptop sales - The Verge',
#    'description': 'Razer has resumed taking orders in the US for some of its Blade 16 gaming laptops with Nvidia 50-serires GPUs, after a temporary pause likely due to US tariffs.',
#    'url': 'https://www.theverge.com/news/651199/razer-blade-16-laptop-sales-resume-us-tariffs',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2025/03/257655_Razer_Blade_16_laptop_2025_5090_ADiBenedetto_0013.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#    'publishedAt': '2025-04-17T20:12:41Z',
#    'content': 'But its hard to tell whats going on with the new Blade 16.\r\nRazer is selling laptops on its site again after a recent and sudden halt.\r\nIn what seemed like a response to ongoing tariff tumult, the US… [+1395 chars]'},
#   {'source': {'id': None, 'name': 'Gematsu'},
#    'author': 'Sal Romano',
#    'title': 'First-person dark fantasy combat game Covenant – Galaxies 2025 trailer - Gematsu',
#    'description': 'Legion Studios has released the latest trailer for Covenant, its upcoming first-person dark fantasy combat game. It is in development for PC (Steam). A release date has yet to be announced. Here is…',
#    'url': 'https://www.gematsu.com/2025/04/first-person-dark-fantasy-combat-game-covenant-galaxies-2025-trailer',
#    'urlToImage': 'https://www.gematsu.com/wp-content/uploads/2025/04/Covenant-Trailer_04-17-25.jpg',
#    'publishedAt': '2025-04-17T20:00:05Z',
#    'content': 'Legion Studios has released the latest trailer for Covenant, its upcoming first-person dark fantasy combat game. It is in development for PC (Steam). A release date has yet to be announced.\r\nHere is … [+2888 chars]'},
#   {'source': {'id': None, 'name': 'Android Authority'},
#    'author': None,
#    'title': 'Google is bringing back the Do Not Disturb shortcut for people who hate Modes - Android Authority',
#    'description': "Google is preparing to re-add a dedicated shortcut for toggling Do Not Disturb mode from Android's Quick Settings panel.",
#    'url': 'https://www.androidauthority.com/android-do-not-disturb-shortcut-3545687/',
#    'urlToImage': 'https://www.androidauthority.com/wp-content/uploads/2025/04/Do_Not_Disturb_mode_settings_in_Android_16_on_Pixel-scaled.jpg',
#    'publishedAt': '2025-04-17T19:16:45Z',
#    'content': '<ul><li>Google is working on re-adding a dedicated shortcut for toggling Do Not Disturb mode from the Quick Settings panel.</li><li>For a long time, Android let users quickly toggle Do Not Disturb mo… [+3436 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Dominic Preston',
#    'title': 'Just look at Huawei’s trifold phone - The Verge',
#    'description': 'The Huawei Mate XT is the first trifold phone anyone can actually buy — here’s what it looks like from every angle.',
#    'url': 'https://www.theverge.com/mobile/650749/huawei-mate-xt-trifoldphotos',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2025/04/huawei-mate-xt-16.jpg?quality=90&strip=all&crop=0%2C10.741906587151%2C100%2C78.516186825698&w=1200',
#    'publishedAt': '2025-04-17T19:06:47Z',
#    'content': '24 hours with the worlds first trifold phone.\r\nAfter 24 hours with Huaweis Mate XT a.k.a. the worlds first trifold smartphone I have this to say for it: the novelty hasnt worn off.\r\nIve tried the Mat… [+3806 chars]'},
#   {'source': {'id': 'ars-technica', 'name': 'Ars Technica'},
#    'author': 'Ryan Whitwam',
#    'title': 'Gemini 2.5 Flash comes to the Gemini app as Google seeks to improve “dynamic thinking” - Ars Technica',
#    'description': 'Gemini 2.5 Flash is ready for you to try in the Gemini app, but it’s starting as a preview.',
#    'url': 'https://arstechnica.com/ai/2025/04/gemini-2-5-flash-comes-to-the-gemini-app-gives-developers-control-over-thinking/',
#    'urlToImage': 'https://cdn.arstechnica.net/wp-content/uploads/2025/03/Gemini-app-1152x648.jpg',
#    'publishedAt': '2025-04-17T19:06:17Z',
#    'content': None},
#   {'source': {'id': None, 'name': '9to5google.com'},
#    'author': 'Abner Li',
#    'title': 'Google Store posts its own Pixel 9a vs. iPhone 16e comparison - 9to5Google',
#    'description': 'Over the years, Google marketing has compared the Pixel to the iPhone. The latest example — Pixel 9a vs. iPhone 16e — makes...',
#    'url': 'http://9to5google.com/2025/04/17/pixel-9a-vs-iphone-16e/',
#    'urlToImage': 'https://i0.wp.com/9to5google.com/wp-content/uploads/sites/4/2025/04/Peony-Pixel-9a-in-hand.jpg?resize=1200%2C628&quality=82&strip=all&ssl=1',
#    'publishedAt': '2025-04-17T17:55:00Z',
#    'content': 'Over the years, Google marketing has compared the Pixel to the iPhone. There was notably the Phone X vs. Pixel 3a Night Sight campaign in 2019. The latest example Pixel 9a vs. iPhone 16e makes for th… [+1714 chars]'},
#   {'source': {'id': None, 'name': 'Blizzard.com'},
#    'author': None,
#    'title': 'Throw Down the Gauntlet and Challenge Friends to a Duel — Warcraft Rumble - Blizzard News',
#    'description': 'Throw down the gauntlet and challenge friends or foes to a duel with the new Friendly Duels feature or see where you stand on the new Player versus Player Seasonal Leaderboard!',
#    'url': 'https://news.blizzard.com/en-us/article/24194657/throw-down-the-gauntlet-and-challenge-friends-to-a-duel',
#    'urlToImage': 'https://bnetcmsus-a.akamaihd.net/cms/blog_header/v8/V828J9J7R9NC1741112371168.png',
#    'publishedAt': '2025-04-17T17:28:00Z',
#    'content': 'Friendly Duels\r\nThrow down the gauntlet and challenge friend or foe to a duel with the new Friendly Duels feature. To duel, tap the PvP tab and then tap on Friendly Duels, copy the code and share it … [+1742 chars]'},
#   {'source': {'id': 'ars-technica', 'name': 'Ars Technica'},
#    'author': 'Ryan Whitwam',
#    'title': 'Google is gifting a year of Gemini Advanced to every college student in the US - Ars Technica',
#    'description': 'Got a .edu email? You can sign up for a free year of Google One AI Premium.',
#    'url': 'https://arstechnica.com/ai/2025/04/google-is-gifting-a-year-of-gemini-advanced-to-every-college-student-in-the-us/',
#    'urlToImage': 'https://cdn.arstechnica.net/wp-content/uploads/2025/03/Gemini-models-march-1-1152x648-1743438208.jpg',
#    'publishedAt': '2025-04-17T16:51:26Z',
#    'content': None},
#   {'source': {'id': None, 'name': 'GameRant'},
#    'author': 'Carley Garcia',
#    'title': 'Lords of the Fallen Releases Major 2.0 Update - Game Rant',
#    'description': 'Version 2.0 of the soulslike title Lords of the Fallen is here, bringing with it some major new features and highly requested improvements.',
#    'url': 'https://gamerant.com/lords-of-the-fallen-20-update-patch-notes/',
#    'urlToImage': 'https://static0.gamerantimages.com/wordpress/wp-content/uploads/2025/04/a-boss-fight-in-lords-of-the-fallen.jpg',
#    'publishedAt': '2025-04-17T16:39:00Z',
#    'content': "Summary\r\n<ul><li>\r\n The Lords of the Fallen Version 2.0 update adds shared progression co-op, more refined combat, a free Friend's Pass, and more.\r\n </li><li>\r\n While the update is now live on all pl… [+5548 chars]"},
#   {'source': {'id': None, 'name': 'Android Central'},
#    'author': 'Nickolas Diaz',
#    'title': "Samsung's One UI 7 rollout returns with a new build for the Galaxy S24 - Android Central",
#    'description': "We're all crossing our fingers that things are stable now.",
#    'url': 'https://www.androidcentral.com/phones/samsung-galaxy/samsung-galaxy-s24-series-one-ui-7-rollout-continues-new-build',
#    'urlToImage': 'https://cdn.mos.cms.futurecdn.net/zxVn5aMDEYed3Vtx6RXggF.jpg',
#    'publishedAt': '2025-04-17T16:30:47Z',
#    'content': "What you need to know\r\n<ul><li>Samsung's One UI 7 rollout as resumed for the Galaxy S24 in South Korea as of today (April 17).</li><li>The continuation features a brand new build after Samsung was fo… [+2759 chars]"},
#   {'source': {'id': None, 'name': 'Wccftech'},
#    'author': None,
#    'title': 'F1 25 to Support Path Tracing (only on PC), Improved Facial Animations with NVIDIA Audio2Face - Wccftech',
#    'description': 'Codemasters announced that F1 25 will support path tracing (only on PC), as well as improved facial animations thanks to NVIDIA Audio2Face.',
#    'url': 'https://wccftech.com/f1-25-to-support-path-tracing-only-on-pc-improved-facial-animations-with-nvidia-audio2face/',
#    'urlToImage': 'https://cdn.wccftech.com/wp-content/uploads/2025/04/PATH-TRACING-F1-25-scaled.jpg',
#    'publishedAt': '2025-04-17T15:45:00Z',
#    'content': 'Codemasters announced today that F1 25 will join the extremely elite club of games supporting path tracing. Just like with all the others (Cyberpunk 2077, Alan Wake 2, Black Myth: Wukong, Indiana Jon… [+2048 chars]'},
#   {'source': {'id': None, 'name': 'TechSpot'},
#    'author': 'Zo Ahmed',
#    'title': 'A real-life Severance keyboard is here, complete with built-in trackball - TechSpot',
#    'description': "In Severance, the keyboards used by Macrodata Refinement – the department where the protagonists work – appear to draw inspiration from Data General's vintage Dasher terminals, popular...",
#    'url': 'https://www.techspot.com/news/107593-real-life-severance-keyboard-here-complete-built-trackball.html',
#    'urlToImage': 'https://www.techspot.com/images2/news/bigimage/2025/04/2025-04-17-image-8.jpg',
#    'publishedAt': '2025-04-17T15:36:00Z',
#    'content': "The big picture: If you've ever wanted to bring a bit of Severance's office dystopia into your real life minus the mind-splitting surgery custom keyboard brand Atomic has you covered. The company jus… [+2193 chars]"},
#   {'source': {'id': None, 'name': 'Phoronix'},
#    'author': None,
#    'title': 'Framework 13 With AMD Ryzen AI 300 Series "Strix Point" Makes For A Great Linux Laptop Review - Phoronix',
#    'description': "Today the review embargo lifts on the Framework 13 with AMD Ryzen AI 300 'Strix Point' SoCs: wow, what an upgrade! I've spent the past week testing out the Framework 13 with the AMD Ryzen AI 9 HX 370 and it's been terrific.",
#    'url': 'https://www.phoronix.com/review/framework-13-amd-strix-point',
#    'urlToImage': 'https://www.phoronix.net/image.php?id=framework-13-amd-strix-point&image=framework_ryzen300_6',
#    'publishedAt': '2025-04-17T15:00:00Z',
#    'content': 'Today the review embargo lifts on the Framework 13 with AMD Ryzen AI 300 "Strix Point" SoCs: wow, what an upgrade! I\'ve spent the past week testing out the Framework 13 with the AMD Ryzen AI 9 HX 370… [+3375 chars]'},
#   {'source': {'id': None, 'name': '9to5google.com'},
#    'author': 'Ben Schoon',
#    'title': 'Google TV Streamer drops to $79 in its first major discount - 9to5Google',
#    'description': 'The Google TV Streamer is getting its first discount, with a sale price of $79, down 20% from its usual price point.',
#    'url': 'http://9to5google.com/2025/04/17/google-tv-streamer-first-discount-sale/',
#    'urlToImage': 'https://i0.wp.com/9to5google.com/wp-content/uploads/sites/4/2024/08/google-tv-streamer-remote-4-3.jpg?resize=1200%2C628&quality=82&strip=all&ssl=1',
#    'publishedAt': '2025-04-17T14:35:00Z',
#    'content': 'The Google TV Streamer launched last year to replace the Chromecast with a new price of $99, a bit of a hard pill to swallow for some. Now, Google is offering the first major discount on the Google T… [+1559 chars]'},
#   {'source': {'id': None, 'name': 'SamMobile'},
#    'author': 'Mihai Matei',
#    'title': "Amid Samsung's One UI 7 delay, Google almost ready to release Android 16 - SamMobile",
#    'description': 'Samsung revealed back in March that it would bring the official One UI 7 update to the Galaxy S24 series and the Galaxy S23 series sometime in April, with the rollout commencing on April 7 and then expanding to more and more devices in the weeks that follow. …',
#    'url': 'https://www.sammobile.com/news/samsung-galaxy-s24-fe-s23-fe-s21-fe-one-ui-7-timeline/',
#    'urlToImage': 'https://www.sammobile.com/wp-content/uploads/2021/05/samsung-clock.jpg',
#    'publishedAt': '2025-04-17T14:03:21Z',
#    'content': None},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Ash Parrish',
#    'title': 'Nintendo shows off Mario Kart World’s new courses, items, and open world features - The Verge',
#    'description': 'Nintendo has held a Mario Kart World direct showing off more gameplay of the Switch 2 launch title.',
#    'url': 'https://www.theverge.com/news/649138/mario-kart-world-direct-nintendo-switch-2-gameplay',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2025/04/NintendoSwitch2_MarioKartWorld_SCRN_GrandPrix_01_a1f79d.png?quality=90&strip=all&crop=0%2C3.4613147178592%2C100%2C93.077370564282&w=1200',
#    'publishedAt': '2025-04-17T13:38:47Z',
#    'content': 'Its Mario Karts world and were all driving in it.\r\nIts Mario Karts world and were all driving in it.\r\nNintendo is possibly hoping to steer the narrative regarding the Switch 2 back in a positive dire… [+2280 chars]'}]}
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
